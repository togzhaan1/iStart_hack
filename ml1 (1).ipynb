# %%
# !pip install ultralytics

from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.5 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
# !pip install ultralytics roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="X9isy4aeIIXMnjnRCJ3S")
project = rf.workspace("decentarathon").project("rust-and-scrach-8kbj7")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Rust-and-Scrach-1 in yolov8:: 100%|██████████| 218/218 [00:00<00:00, 2551.17it/s]

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
# !ls -R /content/Rust-and-Scrach-1
# Out:
# /content/Rust-and-Scrach-1:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
#
# /content/Rust-and-Scrach-1/test:
# images	labels
#
# /content/Rust-and-Scrach-1/test/images:
# 1200x900-17-_jpg.rf.a34eb05648f33162cebbc513f0aafb68.jpg
# 1200x900-18-_jpg.rf.526b38362469631878afd2703731623b.jpg
# 1200x900-24-_jpg.rf.93c201943018c1beff6a38d62c023093.jpg
# 1200x900n-3-_jpg.rf.bfe92e30c75a053ed5ef992348c6a2cc.jpg
# 1539868278119653349_jpg.rf.a9f5d5d4548f03f081905b862d1b1f7d.jpg
# 1_jpg.rf.9ba6b4ce0c8e7850fdda8bfc407b32fb.jpg
# 46db3a029388e6708ce9d945d96f06e1_jpg.rf.e48deea65d4508253512d8009ea5e8ac.jpg
# mbe250_01_jpg.rf.7ea7f933e054d519e5f0651d73a1367d.jpg
# PIC_01231-1024x768-1024x768_jpg.rf.4a8f2f945b262536c3a5593945eaf365.jpg
# vmaitina_0_jpg.rf.be9f06c28bbeba3821acbf0fc9dd9908.jpg
#
# /content/Rust-and-Scrach-1/test/labels:
# 1200x900-17-_jpg.rf.a34eb05648f33162cebbc513f0aafb68.txt
# 1200x900-18-_jpg.rf.526b38362469631878afd2703731623b.txt
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="/content/Rust-and-Scrach-1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.199 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/runs/detect/train7/weights/best.pt")
results = model.predict(
    source="/content/aaaa.jpg",
    conf=0.2,
    save=True
)
# Out:
# image 1/1 /content/aaaa.jpg: 384x640 1 rust, 128.7ms
# Speed: 2.9ms preprocess, 128.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict12

# %%
from IPython.display import Image, display
display(Image(filename="/content/runs/detect/predict10/qwer.jpg"))
